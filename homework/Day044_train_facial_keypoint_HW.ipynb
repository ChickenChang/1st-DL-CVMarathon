# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import keras
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
## set gpu usage
import tensorflow as tf
config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True, per_process_gpu_memory_fraction = 0.9))
session = tf.Session(config=config)
keras.backend.tensorflow_backend.set_session(session)
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0076 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00218, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00218 to 0.00189, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00189 to 0.00185, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00185 to 0.00182, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00182 to 0.00177, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss did not improve from 0.00177
# Epoch 7/150
# 1712/1712 [==============================] - 0s 259us/step - loss: 8.9487e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00177 to 0.00159, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 7.5940e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00159 to 0.00148, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 6.9020e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00148 to 0.00135, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 6.1429e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00135 to 0.00129, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 5.6484e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00129 to 0.00118, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 5.4092e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00118 to 0.00112, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 4.9512e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00112 to 0.00107, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 4.5485e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00107 to 0.00101, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 4.3319e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss improved from 0.00101 to 0.00100, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 4.0631e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss did not improve from 0.00100
# Epoch 17/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 3.9839e-04 - val_loss: 9.7232e-04
#
# Epoch 00017: val_loss improved from 0.00100 to 0.00097, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 3.7083e-04 - val_loss: 9.1945e-04
#
# Epoch 00018: val_loss improved from 0.00097 to 0.00092, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 3.5538e-04 - val_loss: 9.2151e-04
#
# Epoch 00019: val_loss did not improve from 0.00092
# Epoch 20/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 3.4467e-04 - val_loss: 9.1103e-04
#
# Epoch 00020: val_loss improved from 0.00092 to 0.00091, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 3.4287e-04 - val_loss: 8.9189e-04
#
# Epoch 00021: val_loss improved from 0.00091 to 0.00089, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 3.2496e-04 - val_loss: 8.9375e-04
#
# Epoch 00022: val_loss did not improve from 0.00089
# Epoch 23/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 3.1630e-04 - val_loss: 8.6637e-04
#
# Epoch 00023: val_loss improved from 0.00089 to 0.00087, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 3.0784e-04 - val_loss: 8.8204e-04
#
# Epoch 00024: val_loss did not improve from 0.00087
# Epoch 25/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.9245e-04 - val_loss: 8.8325e-04
#
# Epoch 00025: val_loss did not improve from 0.00087
# Epoch 26/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 2.8479e-04 - val_loss: 8.9051e-04
#
# Epoch 00026: val_loss did not improve from 0.00087
# Epoch 27/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 2.8360e-04 - val_loss: 8.1023e-04
#
# Epoch 00027: val_loss improved from 0.00087 to 0.00081, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 2.7500e-04 - val_loss: 8.5249e-04
#
# Epoch 00028: val_loss did not improve from 0.00081
# Epoch 29/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 2.7072e-04 - val_loss: 8.1717e-04
#
# Epoch 00029: val_loss did not improve from 0.00081
# Epoch 30/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 2.6090e-04 - val_loss: 7.8969e-04
#
# Epoch 00030: val_loss improved from 0.00081 to 0.00079, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 2.5400e-04 - val_loss: 8.1729e-04
#
# Epoch 00031: val_loss did not improve from 0.00079
# Epoch 32/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.4252e-04 - val_loss: 8.0895e-04
#
# Epoch 00032: val_loss did not improve from 0.00079
# Epoch 33/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.3643e-04 - val_loss: 7.9785e-04
#
# Epoch 00033: val_loss did not improve from 0.00079
# Epoch 34/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 2.3424e-04 - val_loss: 8.1773e-04
#
# Epoch 00034: val_loss did not improve from 0.00079
# Epoch 35/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 2.3394e-04 - val_loss: 8.2615e-04
#
# Epoch 00035: val_loss did not improve from 0.00079
# Epoch 36/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 2.2929e-04 - val_loss: 8.0109e-04
#
# Epoch 00036: val_loss did not improve from 0.00079
# Epoch 37/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.2705e-04 - val_loss: 7.9431e-04
#
# Epoch 00037: val_loss did not improve from 0.00079
# Epoch 38/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 2.3043e-04 - val_loss: 7.6585e-04
#
# Epoch 00038: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 2.1342e-04 - val_loss: 7.7574e-04
#
# Epoch 00039: val_loss did not improve from 0.00077
# Epoch 40/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 2.1410e-04 - val_loss: 8.2547e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 2.1603e-04 - val_loss: 7.6913e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 2.0320e-04 - val_loss: 7.9601e-04
#
# Epoch 00042: val_loss did not improve from 0.00077
# Epoch 43/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 2.0649e-04 - val_loss: 8.2584e-04
#
# Epoch 00043: val_loss did not improve from 0.00077
# Epoch 44/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 2.0679e-04 - val_loss: 7.6439e-04
#
# Epoch 00044: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.9951e-04 - val_loss: 7.9050e-04
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.9987e-04 - val_loss: 7.7665e-04
#
# Epoch 00046: val_loss did not improve from 0.00076
# Epoch 47/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.9842e-04 - val_loss: 8.6693e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 1.9654e-04 - val_loss: 8.0934e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.9065e-04 - val_loss: 7.8623e-04
#
# Epoch 00049: val_loss did not improve from 0.00076
# Epoch 50/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.9090e-04 - val_loss: 7.7920e-04
#
# Epoch 00050: val_loss did not improve from 0.00076
# Epoch 51/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.8821e-04 - val_loss: 7.8813e-04
#
# Epoch 00051: val_loss did not improve from 0.00076
# Epoch 52/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.8293e-04 - val_loss: 7.8071e-04
#
# Epoch 00052: val_loss did not improve from 0.00076
# Epoch 53/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.8013e-04 - val_loss: 7.5447e-04
#
# Epoch 00053: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.7669e-04 - val_loss: 7.6667e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.7509e-04 - val_loss: 8.0117e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
# Epoch 56/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.7919e-04 - val_loss: 8.1507e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.7463e-04 - val_loss: 7.8684e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.6851e-04 - val_loss: 7.7734e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.6432e-04 - val_loss: 7.6249e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.6653e-04 - val_loss: 7.9514e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.6948e-04 - val_loss: 8.1434e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.6231e-04 - val_loss: 7.9368e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.6215e-04 - val_loss: 7.9764e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.5611e-04 - val_loss: 7.8954e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.5722e-04 - val_loss: 7.6743e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.5956e-04 - val_loss: 8.2540e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.5420e-04 - val_loss: 7.8584e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.5031e-04 - val_loss: 7.9879e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.5026e-04 - val_loss: 8.0208e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.4864e-04 - val_loss: 7.9168e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.4590e-04 - val_loss: 7.4074e-04
#
# Epoch 00071: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 72/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.4294e-04 - val_loss: 7.6959e-04
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.4786e-04 - val_loss: 8.0078e-04
#
# Epoch 00073: val_loss did not improve from 0.00074
# Epoch 74/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 1.4285e-04 - val_loss: 7.9587e-04
#
# Epoch 00074: val_loss did not improve from 0.00074
# Epoch 75/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.4880e-04 - val_loss: 7.9749e-04
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.4268e-04 - val_loss: 8.4705e-04
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 1.4574e-04 - val_loss: 7.7881e-04
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.4171e-04 - val_loss: 7.9294e-04
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.3747e-04 - val_loss: 7.7521e-04
#
# Epoch 00079: val_loss did not improve from 0.00074
# Epoch 80/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.3606e-04 - val_loss: 7.8668e-04
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.3092e-04 - val_loss: 7.6517e-04
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.3020e-04 - val_loss: 7.7094e-04
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.3517e-04 - val_loss: 7.8549e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.3343e-04 - val_loss: 7.6273e-04
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.3156e-04 - val_loss: 7.8058e-04
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.2924e-04 - val_loss: 7.8661e-04
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.2897e-04 - val_loss: 7.4752e-04
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.2671e-04 - val_loss: 7.5851e-04
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.2764e-04 - val_loss: 7.7370e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.2625e-04 - val_loss: 7.4090e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 1.2333e-04 - val_loss: 7.5635e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 1.2534e-04 - val_loss: 7.6056e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.2741e-04 - val_loss: 7.9961e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.2845e-04 - val_loss: 8.0383e-04
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.2646e-04 - val_loss: 7.6627e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.2332e-04 - val_loss: 7.7179e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.1621e-04 - val_loss: 7.7425e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.1829e-04 - val_loss: 8.0114e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.1668e-04 - val_loss: 7.5498e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.1573e-04 - val_loss: 7.7046e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 1.1218e-04 - val_loss: 7.9904e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.1633e-04 - val_loss: 8.2294e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.1456e-04 - val_loss: 7.9353e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 1.1503e-04 - val_loss: 7.9800e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.1144e-04 - val_loss: 7.9469e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.1177e-04 - val_loss: 7.5591e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.0919e-04 - val_loss: 8.2513e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 1.1014e-04 - val_loss: 7.7256e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 1.0760e-04 - val_loss: 8.1007e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.0752e-04 - val_loss: 7.9803e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 1.0967e-04 - val_loss: 7.6980e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.1072e-04 - val_loss: 7.4341e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 1.0810e-04 - val_loss: 7.5923e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.0891e-04 - val_loss: 7.9270e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.0447e-04 - val_loss: 7.7906e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.0026e-04 - val_loss: 7.7519e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.0371e-04 - val_loss: 7.6178e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.0222e-04 - val_loss: 8.0973e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 9.8049e-05 - val_loss: 7.6811e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 9.9894e-05 - val_loss: 7.6420e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 9.9080e-05 - val_loss: 7.7737e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.0181e-04 - val_loss: 7.6217e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 9.8490e-05 - val_loss: 7.7724e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 9.8329e-05 - val_loss: 7.3846e-04
#
# Epoch 00124: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 125/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 9.8416e-05 - val_loss: 7.8089e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 9.8297e-05 - val_loss: 7.8180e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 9.8091e-05 - val_loss: 7.7040e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 9.7403e-05 - val_loss: 8.2325e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 9.8265e-05 - val_loss: 7.6977e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 9.4848e-05 - val_loss: 7.8520e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 9.8304e-05 - val_loss: 7.7871e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 9.4573e-05 - val_loss: 8.0821e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 9.5214e-05 - val_loss: 7.8566e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 9.5704e-05 - val_loss: 7.8355e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 9.4978e-05 - val_loss: 7.8768e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 9.6826e-05 - val_loss: 7.9586e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 9.6537e-05 - val_loss: 7.8128e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 9.1778e-05 - val_loss: 7.7192e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 9.0443e-05 - val_loss: 7.6149e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 9.0878e-05 - val_loss: 8.3014e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 8.6940e-05 - val_loss: 8.0327e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 9.0711e-05 - val_loss: 7.6814e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 9.0784e-05 - val_loss: 8.1262e-04
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 8.9602e-05 - val_loss: 7.8012e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 8.9042e-05 - val_loss: 7.8165e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 8.8457e-05 - val_loss: 7.6729e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 8.8655e-05 - val_loss: 7.6226e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 8.9351e-05 - val_loss: 7.8137e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 8.6998e-05 - val_loss: 7.8832e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 8.5601e-05 - val_loss: 7.7127e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 354us/step - loss: 0.0040 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00199, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00199 to 0.00187, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00187 to 0.00176, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 245us/step - loss: 8.4673e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00176 to 0.00157, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 6.7645e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00157 to 0.00118, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 5.6150e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00118 to 0.00106, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 4.7557e-04 - val_loss: 9.7815e-04
#
# Epoch 00007: val_loss improved from 0.00106 to 0.00098, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 4.2851e-04 - val_loss: 8.8691e-04
#
# Epoch 00008: val_loss improved from 0.00098 to 0.00089, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 3.8582e-04 - val_loss: 8.4501e-04
#
# Epoch 00009: val_loss improved from 0.00089 to 0.00085, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - ETA: 0s - loss: 3.5833e-0 - 1s 239us/step - loss: 3.5784e-04 - val_loss: 7.9869e-04
#
# Epoch 00010: val_loss improved from 0.00085 to 0.00080, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 3.3177e-04 - val_loss: 7.7691e-04
#
# Epoch 00011: val_loss improved from 0.00080 to 0.00078, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 3.1628e-04 - val_loss: 7.7619e-04
#
# Epoch 00012: val_loss improved from 0.00078 to 0.00078, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 2.9498e-04 - val_loss: 7.3239e-04
#
# Epoch 00013: val_loss improved from 0.00078 to 0.00073, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 2.8723e-04 - val_loss: 7.2174e-04
#
# Epoch 00014: val_loss improved from 0.00073 to 0.00072, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 246us/step - loss: 2.7846e-04 - val_loss: 7.2123e-04
#
# Epoch 00015: val_loss improved from 0.00072 to 0.00072, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 245us/step - loss: 2.7016e-04 - val_loss: 7.0166e-04
#
# Epoch 00016: val_loss improved from 0.00072 to 0.00070, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 245us/step - loss: 2.5298e-04 - val_loss: 6.7788e-04
#
# Epoch 00017: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 1s 249us/step - loss: 2.4313e-04 - val_loss: 7.0682e-04
#
# Epoch 00018: val_loss did not improve from 0.00068
# Epoch 19/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 2.4497e-04 - val_loss: 6.6074e-04
#
# Epoch 00019: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 20/150
# 3424/3424 [==============================] - 1s 250us/step - loss: 2.3348e-04 - val_loss: 7.0697e-04
#
# Epoch 00020: val_loss did not improve from 0.00066
# Epoch 21/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 2.2794e-04 - val_loss: 6.8400e-04
#
# Epoch 00021: val_loss did not improve from 0.00066
# Epoch 22/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 2.1939e-04 - val_loss: 6.4085e-04
#
# Epoch 00022: val_loss improved from 0.00066 to 0.00064, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 2.1592e-04 - val_loss: 6.4480e-04
#
# Epoch 00023: val_loss did not improve from 0.00064
# Epoch 24/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 2.1332e-04 - val_loss: 6.3677e-04
#
# Epoch 00024: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 2.0730e-04 - val_loss: 6.7904e-04
#
# Epoch 00025: val_loss did not improve from 0.00064
# Epoch 26/150
# 3424/3424 [==============================] - 1s 229us/step - loss: 1.9652e-04 - val_loss: 6.5851e-04
#
# Epoch 00026: val_loss did not improve from 0.00064
# Epoch 27/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 1.9730e-04 - val_loss: 6.3116e-04
#
# Epoch 00027: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.9411e-04 - val_loss: 6.4086e-04
#
# Epoch 00028: val_loss did not improve from 0.00063
# Epoch 29/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.8435e-04 - val_loss: 6.3041e-04
#
# Epoch 00029: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 30/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 1.8438e-04 - val_loss: 6.3590e-04
#
# Epoch 00030: val_loss did not improve from 0.00063
# Epoch 31/150
# 3424/3424 [==============================] - 1s 249us/step - loss: 1.8223e-04 - val_loss: 6.2428e-04
#
# Epoch 00031: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 32/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 1.7612e-04 - val_loss: 6.3564e-04
#
# Epoch 00032: val_loss did not improve from 0.00062
# Epoch 33/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 1.8075e-04 - val_loss: 6.2948e-04
#
# Epoch 00033: val_loss did not improve from 0.00062
# Epoch 34/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 1.7519e-04 - val_loss: 6.3539e-04
#
# Epoch 00034: val_loss did not improve from 0.00062
# Epoch 35/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.6894e-04 - val_loss: 6.4922e-04
#
# Epoch 00035: val_loss did not improve from 0.00062
# Epoch 36/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.6529e-04 - val_loss: 6.3774e-04
#
# Epoch 00036: val_loss did not improve from 0.00062
# Epoch 37/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 1.6011e-04 - val_loss: 6.1832e-04
#
# Epoch 00037: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 38/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 1.6151e-04 - val_loss: 6.3287e-04
#
# Epoch 00038: val_loss did not improve from 0.00062
# Epoch 39/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.5839e-04 - val_loss: 6.5738e-04
#
# Epoch 00039: val_loss did not improve from 0.00062
# Epoch 40/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 1.6022e-04 - val_loss: 6.3384e-04
#
# Epoch 00040: val_loss did not improve from 0.00062
# Epoch 41/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.5315e-04 - val_loss: 6.0230e-04
#
# Epoch 00041: val_loss improved from 0.00062 to 0.00060, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 1.4997e-04 - val_loss: 6.3994e-04
#
# Epoch 00042: val_loss did not improve from 0.00060
# Epoch 43/150
# 3424/3424 [==============================] - 1s 248us/step - loss: 1.4914e-04 - val_loss: 6.3906e-04
#
# Epoch 00043: val_loss did not improve from 0.00060
# Epoch 44/150
# 3424/3424 [==============================] - 1s 255us/step - loss: 1.4688e-04 - val_loss: 6.3647e-04
#
# Epoch 00044: val_loss did not improve from 0.00060
# Epoch 45/150
# 3424/3424 [==============================] - 1s 248us/step - loss: 1.4623e-04 - val_loss: 6.5334e-04
#
# Epoch 00045: val_loss did not improve from 0.00060
# Epoch 46/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.4343e-04 - val_loss: 6.0992e-04
#
# Epoch 00046: val_loss did not improve from 0.00060
# Epoch 47/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 1.4036e-04 - val_loss: 6.2096e-04
#
# Epoch 00047: val_loss did not improve from 0.00060
# Epoch 48/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.3699e-04 - val_loss: 6.6253e-04
#
# Epoch 00048: val_loss did not improve from 0.00060
# Epoch 49/150
# 3424/3424 [==============================] - 1s 249us/step - loss: 1.3695e-04 - val_loss: 6.1650e-04
#
# Epoch 00049: val_loss did not improve from 0.00060
# Epoch 50/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 1.3858e-04 - val_loss: 6.6018e-04
#
# Epoch 00050: val_loss did not improve from 0.00060
# Epoch 51/150
# 3424/3424 [==============================] - 1s 249us/step - loss: 1.3479e-04 - val_loss: 6.2285e-04
#
# Epoch 00051: val_loss did not improve from 0.00060
# Epoch 52/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.3274e-04 - val_loss: 6.2924e-04
#
# Epoch 00052: val_loss did not improve from 0.00060
# Epoch 53/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.3021e-04 - val_loss: 6.4996e-04
#
# Epoch 00053: val_loss did not improve from 0.00060
# Epoch 54/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 1.2776e-04 - val_loss: 6.1529e-04
#
# Epoch 00054: val_loss did not improve from 0.00060
# Epoch 55/150
# 3424/3424 [==============================] - 1s 246us/step - loss: 1.3050e-04 - val_loss: 6.6523e-04
#
# Epoch 00055: val_loss did not improve from 0.00060
# Epoch 56/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 1.2973e-04 - val_loss: 6.0798e-04
#
# Epoch 00056: val_loss did not improve from 0.00060
# Epoch 57/150
# 3424/3424 [==============================] - 1s 246us/step - loss: 1.2490e-04 - val_loss: 6.6309e-04
#
# Epoch 00057: val_loss did not improve from 0.00060
# Epoch 58/150
# 3424/3424 [==============================] - 1s 248us/step - loss: 1.2642e-04 - val_loss: 6.1234e-04
#
# Epoch 00058: val_loss did not improve from 0.00060
# Epoch 59/150
# 3424/3424 [==============================] - 1s 247us/step - loss: 1.2393e-04 - val_loss: 6.5665e-04
#
# Epoch 00059: val_loss did not improve from 0.00060
# Epoch 60/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.2211e-04 - val_loss: 6.4125e-04
#
# Epoch 00060: val_loss did not improve from 0.00060
# Epoch 61/150
# 3424/3424 [==============================] - 1s 245us/step - loss: 1.1845e-04 - val_loss: 6.1866e-04
#
# Epoch 00061: val_loss did not improve from 0.00060
# Epoch 62/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 1.1762e-04 - val_loss: 6.2099e-04
#
# Epoch 00062: val_loss did not improve from 0.00060
# Epoch 63/150
# 3424/3424 [==============================] - 1s 257us/step - loss: 1.1645e-04 - val_loss: 5.9537e-04
#
# Epoch 00063: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 64/150
# 3424/3424 [==============================] - 1s 247us/step - loss: 1.1505e-04 - val_loss: 6.0283e-04
#
# Epoch 00064: val_loss did not improve from 0.00060
# Epoch 65/150
# 3424/3424 [==============================] - 1s 252us/step - loss: 1.1525e-04 - val_loss: 6.4751e-04
#
# Epoch 00065: val_loss did not improve from 0.00060
# Epoch 66/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.1465e-04 - val_loss: 6.2124e-04
#
# Epoch 00066: val_loss did not improve from 0.00060
# Epoch 67/150
# 3424/3424 [==============================] - 1s 253us/step - loss: 1.1402e-04 - val_loss: 5.9322e-04
#
# Epoch 00067: val_loss improved from 0.00060 to 0.00059, saving model to best_weights_augment.h5
# Epoch 68/150
# 3424/3424 [==============================] - 1s 249us/step - loss: 1.1164e-04 - val_loss: 6.2949e-04
#
# Epoch 00068: val_loss did not improve from 0.00059
# Epoch 69/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 1.1062e-04 - val_loss: 6.3470e-04
#
# Epoch 00069: val_loss did not improve from 0.00059
# Epoch 70/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 1.0842e-04 - val_loss: 6.2877e-04
#
# Epoch 00070: val_loss did not improve from 0.00059
# Epoch 71/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 1.0577e-04 - val_loss: 6.3908e-04
#
# Epoch 00071: val_loss did not improve from 0.00059
# Epoch 72/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.0502e-04 - val_loss: 6.1531e-04
#
# Epoch 00072: val_loss did not improve from 0.00059
# Epoch 73/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 1.0627e-04 - val_loss: 6.3613e-04
#
# Epoch 00073: val_loss did not improve from 0.00059
# Epoch 74/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.0473e-04 - val_loss: 6.2666e-04
#
# Epoch 00074: val_loss did not improve from 0.00059
# Epoch 75/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 1.0635e-04 - val_loss: 6.4153e-04
#
# Epoch 00075: val_loss did not improve from 0.00059
# Epoch 76/150
# 3424/3424 [==============================] - 1s 248us/step - loss: 1.0670e-04 - val_loss: 6.2163e-04
#
# Epoch 00076: val_loss did not improve from 0.00059
# Epoch 77/150
# 3424/3424 [==============================] - 1s 247us/step - loss: 1.0523e-04 - val_loss: 5.9743e-04
#
# Epoch 00077: val_loss did not improve from 0.00059
# Epoch 78/150
# 3424/3424 [==============================] - 1s 230us/step - loss: 1.0099e-04 - val_loss: 6.3171e-04
#
# Epoch 00078: val_loss did not improve from 0.00059
# Epoch 79/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.0256e-04 - val_loss: 6.1153e-04
#
# Epoch 00079: val_loss did not improve from 0.00059
# Epoch 80/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.0082e-04 - val_loss: 6.4154e-04
#
# Epoch 00080: val_loss did not improve from 0.00059
# Epoch 81/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.0121e-04 - val_loss: 6.4552e-04
#
# Epoch 00081: val_loss did not improve from 0.00059
# Epoch 82/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 1.0010e-04 - val_loss: 6.3996e-04
#
# Epoch 00082: val_loss did not improve from 0.00059
# Epoch 83/150
# 3424/3424 [==============================] - 1s 255us/step - loss: 9.8058e-05 - val_loss: 6.2435e-04
#
# Epoch 00083: val_loss did not improve from 0.00059
# Epoch 84/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 9.8507e-05 - val_loss: 6.2621e-04
#
# Epoch 00084: val_loss did not improve from 0.00059
# Epoch 85/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 9.7154e-05 - val_loss: 6.0061e-04
#
# Epoch 00085: val_loss did not improve from 0.00059
# Epoch 86/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 9.6815e-05 - val_loss: 6.3813e-04
#
# Epoch 00086: val_loss did not improve from 0.00059
# Epoch 87/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 9.5405e-05 - val_loss: 6.0576e-04
#
# Epoch 00087: val_loss did not improve from 0.00059
# Epoch 88/150
# 3424/3424 [==============================] - 1s 251us/step - loss: 9.6564e-05 - val_loss: 6.2069e-04
#
# Epoch 00088: val_loss did not improve from 0.00059
# Epoch 89/150
# 3424/3424 [==============================] - 1s 243us/step - loss: 9.6588e-05 - val_loss: 6.0866e-04
#
# Epoch 00089: val_loss did not improve from 0.00059
# Epoch 90/150
# 3424/3424 [==============================] - 1s 249us/step - loss: 9.3539e-05 - val_loss: 6.4627e-04
#
# Epoch 00090: val_loss did not improve from 0.00059
# Epoch 91/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 9.3682e-05 - val_loss: 6.2162e-04
#
# Epoch 00091: val_loss did not improve from 0.00059
# Epoch 92/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 9.5043e-05 - val_loss: 5.9934e-04
#
# Epoch 00092: val_loss did not improve from 0.00059
# Epoch 93/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 9.2225e-05 - val_loss: 6.1718e-04
#
# Epoch 00093: val_loss did not improve from 0.00059
# Epoch 94/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 9.3802e-05 - val_loss: 6.3568e-04
#
# Epoch 00094: val_loss did not improve from 0.00059
# Epoch 95/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 9.4551e-05 - val_loss: 6.3015e-04
#
# Epoch 00095: val_loss did not improve from 0.00059
# Epoch 96/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 9.2851e-05 - val_loss: 6.0762e-04
#
# Epoch 00096: val_loss did not improve from 0.00059
# Epoch 97/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 9.2182e-05 - val_loss: 6.1285e-04
#
# Epoch 00097: val_loss did not improve from 0.00059
# Epoch 98/150
# 3424/3424 [==============================] - 1s 246us/step - loss: 8.7696e-05 - val_loss: 6.1080e-04
#
# Epoch 00098: val_loss did not improve from 0.00059
# Epoch 99/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 9.1674e-05 - val_loss: 6.3801e-04
#
# Epoch 00099: val_loss did not improve from 0.00059
# Epoch 100/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 9.1894e-05 - val_loss: 6.0633e-04
#
# Epoch 00100: val_loss did not improve from 0.00059
# Epoch 101/150
# 3424/3424 [==============================] - 1s 226us/step - loss: 9.4422e-05 - val_loss: 6.0427e-04
#
# Epoch 00101: val_loss did not improve from 0.00059
# Epoch 102/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.8452e-05 - val_loss: 6.3312e-04
#
# Epoch 00102: val_loss did not improve from 0.00059
# Epoch 103/150
# 3424/3424 [==============================] - 1s 247us/step - loss: 8.8058e-05 - val_loss: 6.3461e-04
#
# Epoch 00103: val_loss did not improve from 0.00059
# Epoch 104/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 8.8148e-05 - val_loss: 6.3575e-04
#
# Epoch 00104: val_loss did not improve from 0.00059
# Epoch 105/150
# 3424/3424 [==============================] - 1s 247us/step - loss: 8.7053e-05 - val_loss: 5.8903e-04
#
# Epoch 00105: val_loss improved from 0.00059 to 0.00059, saving model to best_weights_augment.h5
# Epoch 106/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 8.7627e-05 - val_loss: 6.1643e-04
#
# Epoch 00106: val_loss did not improve from 0.00059
# Epoch 107/150
# 3424/3424 [==============================] - 1s 252us/step - loss: 8.6731e-05 - val_loss: 6.2697e-04
#
# Epoch 00107: val_loss did not improve from 0.00059
# Epoch 108/150
# 3424/3424 [==============================] - 1s 245us/step - loss: 8.7754e-05 - val_loss: 6.1061e-04
#
# Epoch 00108: val_loss did not improve from 0.00059
# Epoch 109/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 8.6845e-05 - val_loss: 6.0645e-04
#
# Epoch 00109: val_loss did not improve from 0.00059
# Epoch 110/150
# 3424/3424 [==============================] - 1s 253us/step - loss: 8.5361e-05 - val_loss: 6.0053e-04
#
# Epoch 00110: val_loss did not improve from 0.00059
# Epoch 111/150
# 3424/3424 [==============================] - 1s 249us/step - loss: 8.6559e-05 - val_loss: 6.2923e-04
#
# Epoch 00111: val_loss did not improve from 0.00059
# Epoch 112/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 8.6758e-05 - val_loss: 6.2949e-04
#
# Epoch 00112: val_loss did not improve from 0.00059
# Epoch 113/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.6249e-05 - val_loss: 6.3201e-04
#
# Epoch 00113: val_loss did not improve from 0.00059
# Epoch 114/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 8.5013e-05 - val_loss: 6.1967e-04
#
# Epoch 00114: val_loss did not improve from 0.00059
# Epoch 115/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 8.4546e-05 - val_loss: 6.0942e-04
#
# Epoch 00115: val_loss did not improve from 0.00059
# Epoch 116/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 8.3847e-05 - val_loss: 6.3828e-04
#
# Epoch 00116: val_loss did not improve from 0.00059
# Epoch 117/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 8.2910e-05 - val_loss: 6.2531e-04
#
# Epoch 00117: val_loss did not improve from 0.00059
# Epoch 118/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.0980e-05 - val_loss: 6.0295e-04
#
# Epoch 00118: val_loss did not improve from 0.00059
# Epoch 119/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.0519e-05 - val_loss: 6.1181e-04
#
# Epoch 00119: val_loss did not improve from 0.00059
# Epoch 120/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 8.2573e-05 - val_loss: 6.2247e-04
#
# Epoch 00120: val_loss did not improve from 0.00059
# Epoch 121/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 8.2379e-05 - val_loss: 6.2280e-04
#
# Epoch 00121: val_loss did not improve from 0.00059
# Epoch 122/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.1491e-05 - val_loss: 6.4403e-04
#
# Epoch 00122: val_loss did not improve from 0.00059
# Epoch 123/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 8.1390e-05 - val_loss: 6.2776e-04
#
# Epoch 00123: val_loss did not improve from 0.00059
# Epoch 124/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 8.1068e-05 - val_loss: 6.0638e-04
#
# Epoch 00124: val_loss did not improve from 0.00059
# Epoch 125/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 8.3862e-05 - val_loss: 6.0658e-04
#
# Epoch 00125: val_loss did not improve from 0.00059
# Epoch 126/150
# 3424/3424 [==============================] - 1s 229us/step - loss: 8.3380e-05 - val_loss: 6.6157e-04
#
# Epoch 00126: val_loss did not improve from 0.00059
# Epoch 127/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 8.0593e-05 - val_loss: 6.3820e-04
#
# Epoch 00127: val_loss did not improve from 0.00059
# Epoch 128/150
# 3424/3424 [==============================] - 1s 245us/step - loss: 8.1086e-05 - val_loss: 6.2972e-04
#
# Epoch 00128: val_loss did not improve from 0.00059
# Epoch 129/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 8.2482e-05 - val_loss: 6.2930e-04
#
# Epoch 00129: val_loss did not improve from 0.00059
# Epoch 130/150
# 3424/3424 [==============================] - 1s 245us/step - loss: 7.9758e-05 - val_loss: 6.3894e-04
#
# Epoch 00130: val_loss did not improve from 0.00059
# Epoch 131/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 8.1631e-05 - val_loss: 6.0962e-04
#
# Epoch 00131: val_loss did not improve from 0.00059
# Epoch 132/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 8.1630e-05 - val_loss: 6.1442e-04
#
# Epoch 00132: val_loss did not improve from 0.00059
# Epoch 133/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.9423e-05 - val_loss: 6.2651e-04
#
# Epoch 00133: val_loss did not improve from 0.00059
# Epoch 134/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.7576e-05 - val_loss: 6.3031e-04
#
# Epoch 00134: val_loss did not improve from 0.00059
# Epoch 135/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.8730e-05 - val_loss: 6.3799e-04
#
# Epoch 00135: val_loss did not improve from 0.00059
# Epoch 136/150
# 3424/3424 [==============================] - 1s 253us/step - loss: 7.9736e-05 - val_loss: 6.2574e-04
#
# Epoch 00136: val_loss did not improve from 0.00059
# Epoch 137/150
# 3424/3424 [==============================] - 1s 248us/step - loss: 7.9647e-05 - val_loss: 6.2157e-04
#
# Epoch 00137: val_loss did not improve from 0.00059
# Epoch 138/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 8.1123e-05 - val_loss: 6.0543e-04
#
# Epoch 00138: val_loss did not improve from 0.00059
# Epoch 139/150
# 3424/3424 [==============================] - 1s 243us/step - loss: 7.8926e-05 - val_loss: 6.5487e-04
#
# Epoch 00139: val_loss did not improve from 0.00059
# Epoch 140/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 7.9173e-05 - val_loss: 6.2197e-04
#
# Epoch 00140: val_loss did not improve from 0.00059
# Epoch 141/150
# 3424/3424 [==============================] - 1s 230us/step - loss: 7.8080e-05 - val_loss: 6.3351e-04
#
# Epoch 00141: val_loss did not improve from 0.00059
# Epoch 142/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 7.5862e-05 - val_loss: 6.2388e-04
#
# Epoch 00142: val_loss did not improve from 0.00059
# Epoch 143/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.7616e-05 - val_loss: 6.3194e-04
#
# Epoch 00143: val_loss did not improve from 0.00059
# Epoch 144/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 7.6050e-05 - val_loss: 6.0503e-04
#
# Epoch 00144: val_loss did not improve from 0.00059
# Epoch 145/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 7.5344e-05 - val_loss: 6.2874e-04
#
# Epoch 00145: val_loss did not improve from 0.00059
# Epoch 146/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 7.6225e-05 - val_loss: 6.3374e-04
#
# Epoch 00146: val_loss did not improve from 0.00059
# Epoch 147/150
# 3424/3424 [==============================] - 1s 243us/step - loss: 8.1330e-05 - val_loss: 6.3111e-04
#
# Epoch 00147: val_loss did not improve from 0.00059
# Epoch 148/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 7.8930e-05 - val_loss: 6.1289e-04
#
# Epoch 00148: val_loss did not improve from 0.00059
# Epoch 149/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 7.7724e-05 - val_loss: 6.2543e-04
#
# Epoch 00149: val_loss did not improve from 0.00059
# Epoch 150/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 7.7480e-05 - val_loss: 6.1325e-04
#
# Epoch 00150: val_loss did not improve from 0.00059

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
